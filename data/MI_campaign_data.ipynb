# %%
import pandas as pd
import os
import re

# %% [markdown]
# Notes about the dataset here from the readme
#
# datafile path: "/Users/necabotheking/Documents/Data Dump/2023-fall-clinic"
# /Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/MI_campaign_data.ipynb
#
# read in as a corpus and string replace

# %%
# code to replace double tab with single 
file = '/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/Contributions/2018_mi_cfr_contributions_03.txt'
df = pd.read_csv(file, delimiter="\t", encoding="mac_roman", header=None, names=["doc_seq_no", "page_no", "contribution_id",
                                                                                                "cont_detail_id", "doc_stmnt_year", "doc_type_desc", 
                                                                                                "com_legal_name", "common_name", "cfr_com_id",	"com_type",	
                                                                                                "can_first_name",	"can_last_name", "contribtype",	"f_name", 
                                                                                                "l_name_or_org", "address",	"city",	"state", "zip",	"occupation", 
                                                                                                "employer",	"received_date", "amount",	"aggregate", "extra_desc"], low_memory=False, on_bad_lines='warn')

df.head(3)
# Out:
# Skipping line 275183: expected 26 fields, saw 27
#         doc_seq_no  page_no  contribution_id  cont_detail_id  \
# 472254           0   464000                0            2018
# 472254           0   464001                0            2018
# 472254           0   464002                0            2018
#
#               doc_stmnt_year  \
# 472254  OCTOBER QUARTERLY CS
# 472254  OCTOBER QUARTERLY CS
# 472254  OCTOBER QUARTERLY CS
#
#                                             doc_type_desc  \
# 472254  UAW MICHIGAN VOLUNTARY POLITICAL ACTION COMMITTEE
# 472254  UAW MICHIGAN VOLUNTARY POLITICAL ACTION COMMITTEE
# 472254  UAW MICHIGAN VOLUNTARY POLITICAL ACTION COMMITTEE
#
#                               com_legal_name  common_name cfr_com_id com_type  \
# 472254  UAW MICHIGAN VOLUNTARY POLITICAL ACT       508347        IND      NaN
# 472254  UAW MICHIGAN VOLUNTARY POLITICAL ACT       508347        IND      NaN
# ...

# %%
file_path = '/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/Contributions/2018_mi_cfr_contributions_03.txt'
data = []

with open(file_path, 'r', encoding='latin-1') as file:
    content = file.read()
    content_with_commas = content.replace('\t+', ',')
    df = pd.read_csv(content_with_commas, delimiter=",", encoding="mac_roman", header=None, names=["doc_seq_no", "page_no", "contribution_id",
                                                                                                "cont_detail_id", "doc_stmnt_year", "doc_type_desc", 
                                                                                                "com_legal_name", "common_name", "cfr_com_id",	"com_type",	
                                                                                                "can_first_name",	"can_last_name", "contribtype",	"f_name", 
                                                                                                "l_name_or_org", "address",	"city",	"state", "zip",	"occupation", 
                                                                                                "employer",	"received_date", "amount",	"aggregate", "extra_desc"], low_memory=False)
    
# with open(file_path, 'w', encoding='latin-1') as file:
#     file.write(content_with_commas)

# %%
error_files = []

# NOTE: THE FUNCTION BELOW NEEDS TO BE CHANGED THE STRING SEARCHES FOR 00 THROUGHOUT THE FUNCTION. USE REGEX TO SEARCH FOR THE VALUES AT 
# THE END OF THE FILE NAME AND BASE THE FUNCTION BELOW ON THAT 

filepath = "/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/Contributions/"

for file in os.listdir(filepath):
    try:
       if file.endswith('00.txt'):
        #if file contains "00" read in the headers 
            df = pd.read_csv(file, delimiter="\t", encoding="mac_roman", usecols=["doc_seq_no", "page_no", "contribution_id",
                                                                                                "cont_detail_id", "doc_stmnt_year", "doc_type_desc", 
                                                                                                "com_legal_name", "common_name", "cfr_com_id",	"com_type",	
                                                                                                "can_first_name",	"can_last_name", "contribtype",	"f_name", 
                                                                                                "l_name_or_org", "address",	"city",	"state", "zip",	"occupation", 
                                                                                                "employer",	"received_date", "amount",	"aggregate", "extra_desc"], low_memory=False)
       else:
           # need to add the column names
           df = pd.read_csv(file, delimiter="\t", encoding="mac_roman", header=None, names=["doc_seq_no", "page_no", "contribution_id",
                                                                                                "cont_detail_id", "doc_stmnt_year", "doc_type_desc", 
                                                                                                "com_legal_name", "common_name", "cfr_com_id",	"com_type",	
                                                                                                "can_first_name",	"can_last_name", "contribtype",	"f_name", 
                                                                                                "l_name_or_org", "address",	"city",	"state", "zip",	"occupation", 
                                                                                                "employer",	"received_date", "amount",	"aggregate", "extra_desc"], low_memory=False)
        
    except pd.errors.ParserError:
        # Handle the ParserError (e.g., print an error message)
        print(f"ParserError encountered in file: {file}")
        
        # Add the file to the list of error_files
        error_files.append(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/MI_campaign_data.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell:/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/MI_campaign_data.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a>         df = pd.read_csv(file, delimiter="\t", encoding="mac_roman", usecols=["doc_seq_no", "page_no", "contribution_id",
#      <a href='vscode-notebook-cell:/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/MI_campaign_data.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a>                                                                                             "cont_detail_id", "doc_stmnt_year", "doc_type_desc",
# ...

# %%
# read in the data depending on the format of the file name., 00 will have the headers while 01 and beyond will not have the headers
# read in the txt files for 2023

def read_txt_data(filepath):
    """
    Reads in the Michigan Campaign Finance Data
    
    Inputs: filepath (str): filepath to the dataset
    
    Returns: df (Pandas DataFrame): Pandas DataFrame from the filepath
    """
    print(f"reading {filepath}")

    if "00" in filepath:
    #if file contains "00" read in the headers 
        df = pd.read_csv(filepath, delimiter="\t", encoding="mac_roman", usecols=["doc_seq_no", "page_no", "contribution_id",
                                                                                            "cont_detail_id", "doc_stmnt_year", "doc_type_desc", 
                                                                                            "com_legal_name", "common_name", "cfr_com_id",	"com_type",	
                                                                                            "can_first_name",	"can_last_name", "contribtype",	"f_name", 
                                                                                            "l_name_or_org", "address",	"city",	"state", "zip",	"occupation", 
                                                                                            "employer",	"received_date", "amount",	"aggregate", "extra_desc"], low_memory=False, on_bad_lines='warn')
    else:
        # files without "00" don't contain headers, set the headers
        df = pd.read_csv(filepath, delimiter="\t", encoding="mac_roman", header=None, names=["doc_seq_no", "page_no", "contribution_id",
                                                                                                "cont_detail_id", "doc_stmnt_year", "doc_type_desc", 
                                                                                                "com_legal_name", "common_name", "cfr_com_id",	"com_type",	
                                                                                                "can_first_name",	"can_last_name", "contribtype",	"f_name", 
                                                                                                "l_name_or_org", "address",	"city",	"state", "zip",	"occupation", 
                                                                                                "employer",	"received_date", "amount",	"aggregate", "extra_desc"], low_memory=False, on_bad_lines='warn')
    print(f"finished reading {filepath}")
    return df
        
    
def concat_years():
    """
    Concatenates the years of election data to create a 1995 to 2023 dataframe
    
    Inputs: None
    
    Returns: merged_df (Pandas DataFrame): Merged dataFrame of MI finance data
    """
    filepath = os.chdir("/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/Contributions")
    merged_df = pd.DataFrame(columns=range(25))
    
    for file in os.listdir(filepath):
            df = read_txt_data(file)
    
            merged_df.columns = df.columns
            merged_df = pd.concat([merged_df, df])
    return merged_df

# %% [markdown]
# Conduct an analysis on the 2014-2023 data to see what races are represented and other factors.
# Add  the README to the Google Drive
#
# # string replace double tab with extra tabs
#
# Questions:
#
#     Why is the 2023 data split into nameless (lacking a number) sections?
#
# Mistake on the part of the Michigan Secretary of State

# %%
pd.set_option('display.max_columns', None)

# %%
# read in the 2023 00 data and compare
df2 = pd.read_csv("2023_mi_cfr_contributions_00.txt", delimiter="	", encoding="mac_roman", usecols=["doc_seq_no", "page_no", "contribution_id",
                                                                                                "cont_detail_id", "doc_stmnt_year", "doc_type_desc", 
                                                                                                "com_legal_name", "common_name",	"cfr_com_id",	"com_type",	
                                                                                                "can_first_name",	"can_last_name", "contribtype",	"f_name", 
                                                                                                "l_name_or_org", "address",	"city",	"state",	"zip",	"occupation", 
                                                                                                "employer",	"received_date", "amount",	"aggregate",	"extra_desc"], low_memory=False)
df2.head(5)
# Out:
#    doc_seq_no  page_no  contribution_id  cont_detail_id  doc_stmnt_year  \
# 0      540263        0             4204               0            2023
# 1      540263        0             4205               0            2023
# 2      540263        0             4206               0            2023
# 3      540263        0             4207               0            2023
# 4      540263        0             4208               0            2023
#
#           doc_type_desc             com_legal_name                common_name  \
# 0  JANUARY QUARTERLY CS  HUMAN RIGHTS CAMPAIGN PAC  HUMAN RIGHTS CAMPAIGN PAC
# 1  JANUARY QUARTERLY CS  HUMAN RIGHTS CAMPAIGN PAC  HUMAN RIGHTS CAMPAIGN PAC
# 2  JANUARY QUARTERLY CS  HUMAN RIGHTS CAMPAIGN PAC  HUMAN RIGHTS CAMPAIGN PAC
# 3  JANUARY QUARTERLY CS  HUMAN RIGHTS CAMPAIGN PAC  HUMAN RIGHTS CAMPAIGN PAC
# 4  JANUARY QUARTERLY CS  HUMAN RIGHTS CAMPAIGN PAC  HUMAN RIGHTS CAMPAIGN PAC
#
#    cfr_com_id com_type can_first_name can_last_name  \
# ...

# %%
df2.tail(5)
# Out:
#         doc_seq_no  page_no  contribution_id  cont_detail_id  doc_stmnt_year  \
# 499994      550071        0         19677306        19547439            2023
# 499995      550071        0         19677306        19547440            2023
# 499996      550071        0         19677306        19547441            2023
# 499997      550071        0         19677306        19547442            2023
# 499998      550071        0         19677306        19547443            2023
#
#             doc_type_desc                                     com_legal_name  \
# 499994  JULY QUARTERLY CS  UNITED FOOD AND COMMERCIAL WORKERS ACTIVE BALL...
# 499995  JULY QUARTERLY CS  UNITED FOOD AND COMMERCIAL WORKERS ACTIVE BALL...
# 499996  JULY QUARTERLY CS  UNITED FOOD AND COMMERCIAL WORKERS ACTIVE BALL...
# 499997  JULY QUARTERLY CS  UNITED FOOD AND COMMERCIAL WORKERS ACTIVE BALL...
# 499998  JULY QUARTERLY CS  UNITED FOOD AND COMMERCIAL WORKERS ACTIVE BALL...
#
# ...

# %% [markdown]
# Note: The contributions and contributions_00 data are the same. There must be an ongoing error, that will not allow the former to be deleted from the Michigan Secretary of State website.

# %%
concat_years()
# Out:
# reading 2018_mi_cfr_contributions_03.txt
# Skipping line 275183: expected 26 fields, saw 27
# finished reading 2018_mi_cfr_contributions_03.txt
# reading 2022_mi_cfr_contributions_01.txt
# Skipping line 109976: expected 26 fields, saw 27
# Skipping line 134574: expected 26 fields, saw 27
# Skipping line 152620: expected 26 fields, saw 27
# Skipping line 152751: expected 26 fields, saw 27
# finished reading 2022_mi_cfr_contributions_01.txt
# reading 2022_mi_cfr_contributions_00.txt
# finished reading 2022_mi_cfr_contributions_00.txt
# reading 1998_mi_cfr_contributions.txt
# finished reading 1998_mi_cfr_contributions.txt
# reading 2018_mi_cfr_contributions_02.txt
# Skipping line 183906: expected 26 fields, saw 27
# finished reading 2018_mi_cfr_contributions_02.txt
# reading 2018_mi_cfr_contributions_00.txt
# finished reading 2018_mi_cfr_contributions_00.txt
# reading 2022_mi_cfr_contributions_02.txt
# Skipping line 106811: expected 26 fields, saw 28
# ...

# %% [markdown]
# ## 2023 Campaign Data Exploratory Data Analysis
#
# ### Notes
# Setting ```index_col=False``` allows the files without the header to be read in correctly (otherwise Pandas uses the ```doc_seq_no``` column as the header).
# The column types are not being read in correctly, the amount column was read in as an object.
#
# ### Findings
#
# There is a column witha  $0.0 contribution and others with only $1. The largest contribution was $32800.0 to elect Houston James as to MI State Senate.

# %%
## The values below will be used as constants 

CONTRIBUTIONS_COLS = ["doc_seq_no", "page_no", "contribution_id", 
"cont_detail_id", "doc_stmnt_year", "doc_type_desc", 
"com_legal_name", "common_name", "cfr_com_id",	"com_type",	
"can_first_name",	"can_last_name", "contribtype",	"f_name", 
"l_name_or_org", "address",	"city",	"state", "zip",	"occupation", 
"employer",	"received_date", "amount",	"aggregate", "extra_desc"]

EXPENDITURES_COLS = ["doc_seq_no",	"expenditure_type",	"gub_account_type", 
"gub_elec_type",	"page_no",	"expense_id",	"detail_id",	
"doc_stmnt_year",	"doc_type_desc", "com_legal_name",	
"common_name",	"cfr_com_id",	"com_type",	"schedule_desc",	
"exp_desc", "purpose",	"extra_desc",	"f_name",	"lname_or_org",	
"address",	"city",	"state", "zip", "exp_date",	"amount",	"state_loc",	
"supp_opp", "can_or_ballot", "county",	"debt_payment",	"vend_name",	
"vend_addr",	"vend_city",	"vend_state",	"vend_zip",	"gotv_ink_ind",	"fundraiser"]

# %%
def read_2023_contribution_data():
    """
    Reads in the 2023 contribution data
    
    Inputs: None
    
    Returns: merges_df (Pandas DataFrame): merged Pandas DataFrame of 2023 contribution data
    """
    df = pd.read_csv("/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/Contributions/2023_mi_cfr_contributions_00.txt", delimiter="\t", encoding="mac_roman", usecols=["doc_seq_no", "page_no", "contribution_id",
                                                                                                "cont_detail_id", "doc_stmnt_year", "doc_type_desc", 
                                                                                                "com_legal_name", "common_name", "cfr_com_id",	"com_type",	
                                                                                                "can_first_name",	"can_last_name", "contribtype",	"f_name", 
                                                                                                "l_name_or_org", "address",	"city",	"state", "zip",	"occupation", 
                                                                                                "employer",	"received_date", "amount",	"aggregate", "extra_desc"], low_memory=True)

    df2 =  pd.read_csv("/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/Contributions/2023_mi_cfr_contributions_01.txt", index_col=False, delimiter="\t", encoding="mac_roman", header=None, names=["doc_seq_no", "page_no", "contribution_id",
                                                                                                    "cont_detail_id", "doc_stmnt_year", "doc_type_desc", 
                                                                                                    "com_legal_name", "common_name", "cfr_com_id",	"com_type",	
                                                                                                    "can_first_name",	"can_last_name", "contribtype",	"f_name", 
                                                                                                    "l_name_or_org", "address",	"city",	"state", "zip",	"occupation", 
                                                                                                    "employer",	"received_date", "amount",	"aggregate", "extra_desc"], low_memory=True, on_bad_lines='warn')

    merged_df = pd.concat([df, df2])
    
    return merged_df

# %%
def read_2023_expenditure_data():
    """
    REads in the 2023 expenditure data
    
    Inputs: None
    
    Returns: df (Pandas DataFrame): DataFrame of 2023 expenditure data
    """
    df = pd.read_csv("/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/Expenditures/2023_mi_cfr_expenditures.txt", delimiter="\t+", encoding="mac_roman", usecols=["doc_seq_no",	"expenditure_type",	"gub_account_type",	
                                                                                                                                                                                         "gub_elec_type",	"page_no",	"expense_id",	"detail_id",	
                                                                                                                                                                                         "doc_stmnt_year",	"doc_type_desc", "com_legal_name",	
                                                                                                                                                                                         "common_name",	"cfr_com_id",	"com_type",	"schedule_desc",	
                                                                                                                                                                                         "exp_desc", "purpose",	"extra_desc",	"f_name",	"lname_or_org",	
                                                                                                                                                                                         "address",	"city",	"state", "zip", "exp_date",	"amount",	"state_loc",	
                                                                                                                                                                                         "supp_opp", "can_or_ballot", "county",	"debt_payment",	"vend_name",	
                                                                                                                                                                                         "vend_addr",	"vend_city",	"vend_state",	"vend_zip",	"gotv_ink_ind",	"fundraiser"])
    return df

# %%
merged_df = read_2023_contribution_data()
merged_df.head()
# Out:
# /var/folders/wp/m7xdfypx2nz0j0wvwl3qn2tw0000gn/T/ipykernel_63807/445353373.py:9: DtypeWarning: Columns (10,11,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/Contributions/2023_mi_cfr_contributions_00.txt", delimiter="\t", encoding="mac_roman", usecols=["doc_seq_no", "page_no", "contribution_id",
#    doc_seq_no  page_no  contribution_id  cont_detail_id  doc_stmnt_year  \
# 0      540263        0             4204               0            2023
# 1      540263        0             4205               0            2023
# 2      540263        0             4206               0            2023
# 3      540263        0             4207               0            2023
# 4      540263        0             4208               0            2023
#
#           doc_type_desc             com_legal_name                common_name  \
# ...

# %%
exp_df = read_2023_expenditure_data()
# Out:
# /var/folders/wp/m7xdfypx2nz0j0wvwl3qn2tw0000gn/T/ipykernel_63807/589852513.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/Expenditures/2023_mi_cfr_expenditures.txt", delimiter="\t+", encoding="mac_roman", usecols=["doc_seq_no",	"expenditure_type",	"gub_account_type",

# %%
exp_df.head()
# Out:
#    doc_seq_no expenditure_type gub_account_type gub_elec_type  page_no  \
# 0      539744               1B                                       0
# 1      539744               1B                                       0
# 2      539744               1B                                       0
# 3      539744               1B                                       0
# 4      539744               1B                                       0
#
#    expense_id  detail_id  doc_stmnt_year doc_type_desc  \
# 0        4308          0            2023     ANNUAL CS
# 1        4314          0            2023     ANNUAL CS
# 2        4315          0            2023     ANNUAL CS
# 3        4316          0            2023     ANNUAL CS
# 4        4317          0            2023     ANNUAL CS
#
#                      com_legal_name                       common_name  \
# 0  COMMITTEE TO ELECT GARY MITCHELL  COMMITTEE TO ELECT GARY MITCHELL
# ...

# %%
merged_df['amount'] = pd.to_numeric(df['amount'], errors='coerce')
# changes the amount column from dtype object to numeric

df.nlargest(1, "amount" )
# Out:
#         doc_seq_no  page_no  contribution_id  cont_detail_id  doc_stmnt_year  \
# 420660      549365        0             4657               0            2023
#
#             doc_type_desc                    com_legal_name  \
# 420660  JULY QUARTERLY CS  COMMUNITY TO ELECT HOUSTON JAMES
#
#                              common_name  cfr_com_id com_type can_first_name  \
# 420660  COMMUNITY TO ELECT HOUSTON JAMES      520841      CAN        HOUSTON
#
#        can_last_name                     contribtype                f_name  \
# 420660         JAMES  LOAN FROM A PERSON              HOUSTON
#
#                                l_name_or_org              address  \
# 420660  JAMES                                 28442 DAWNRIDGE DR.
#
#                         city state         zip    occupation      employer  \
# 420660  FLAT ROCK               MI  48134-0000  NOT EMPLOYED  NOT EMPLOYED
#
#        received_date   amount  aggregate  extra_desc
# ...

# %%
merged_df.nsmallest(5, "amount" )
# Out:
#         doc_seq_no  page_no  contribution_id  cont_detail_id  doc_stmnt_year  \
# 137753      545429        0             4950               0            2023
# 58860       542270        0             4398               0            2023
# 58928       542270        0             4706               0            2023
# 58860       550188        0            79595               0            2023
# 58928       550188        0            79665               0            2023
#
#             doc_type_desc                                  com_legal_name  \
# 137753  AMENDED ANNUAL CS  MEGAN COTTINGTON HEATH FOR CIRCUIT COURT JUDGE
# 58860           ANNUAL CS  MEGAN COTTINGTON HEATH FOR CIRCUIT COURT JUDGE
# 58928           ANNUAL CS  MEGAN COTTINGTON HEATH FOR CIRCUIT COURT JUDGE
# 58860   JULY QUARTERLY CS              MICHIGAN LABORERS POLITICAL LEAGUE
# 58928   JULY QUARTERLY CS              MICHIGAN LABORERS POLITICAL LEAGUE
#
# ...

# %%
# reading 2018_mi_cfr_contributions_03.txt has an error test changing the file in place 

def bug_fix_me_baby_one_more_time():
    """
    """
pass

pattern = r'\s+|\t+'
replacement = ','

def bug_fix_the_remix(input_path, output_path):
    """
    """
    with open(input_path ,'r', encoding='latin-1') as input_file, open(output_path, 'w', encoding='latin-1', newline='') as output_file:
        content = input_file.read()
        modified_content = re.sub(pattern, replacement, content)
        output_file.write(modified_content)

def bug_fix(input_path, output_path):
    """
    """
    with open(input_path ,'r', encoding='latin-1') as input_file, open(output_path, 'w', encoding='latin-1') as output_file:
        for line in input_file:
            line_with_commas = line.replace('\t', ',')
            output_file.write(line_with_commas)

# %%
input_path = '/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/Contributions/2018_mi_cfr_contributions_03.txt'
output_path = '/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/Contributions/EDITED_2018_mi_cfr_contributions_03.txt'

#bug_fix(input_path, output_path) 
bug_fix(input_path, output_path)

# %%
path = '/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/Contributions/EDITED_2018_mi_cfr_contributions_03.txt'

df3 =  pd.read_csv(path, index_col=False, delimiter=",", encoding="mac_roman", header=None, names=["doc_seq_no", "page_no", "contribution_id",
                                                                                                    "cont_detail_id", "doc_stmnt_year", "doc_type_desc", 
                                                                                                    "com_legal_name", "common_name", "cfr_com_id",	"com_type",	
                                                                                                    "can_first_name",	"can_last_name", "contribtype",	"f_name", 
                                                                                                    "l_name_or_org", "address",	"city",	"state", "zip",	"occupation", 
                                                                                                    "employer",	"received_date", "amount",	"aggregate", "extra_desc"], low_memory=True, skipinitialspace='True')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/MI_campaign_data.ipynb Cell 24 line 3
#       <a href='vscode-notebook-cell:/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/MI_campaign_data.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> path = '/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/Contributions/EDITED_2018_mi_cfr_contributions_03.txt'
# ----> <a href='vscode-notebook-cell:/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/MI_campaign_data.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> df3 =  pd.read_csv(path, index_col=False, delimiter=",", encoding="mac_roman", header=None, names=["doc_seq_no", "page_no", "contribution_id",
# ...

# %%
df3.head()
# Out:
#    doc_seq_no  page_no  contribution_id  cont_detail_id  doc_stmnt_year  \
# 0      472254        0           464000               0            2018
# 1      472254        0           464001               0            2018
# 2      472254        0           464002               0            2018
# 3      472254        0           464003               0            2018
# 4      472254        0           464004               0            2018
#
#           doc_type_desc                                     com_legal_name  \
# 0  OCTOBER QUARTERLY CS  UAW MICHIGAN VOLUNTARY POLITICAL ACTION COMMITTEE
# 1  OCTOBER QUARTERLY CS  UAW MICHIGAN VOLUNTARY POLITICAL ACTION COMMITTEE
# 2  OCTOBER QUARTERLY CS  UAW MICHIGAN VOLUNTARY POLITICAL ACTION COMMITTEE
# 3  OCTOBER QUARTERLY CS  UAW MICHIGAN VOLUNTARY POLITICAL ACTION COMMITTEE
# 4  OCTOBER QUARTERLY CS  UAW MICHIGAN VOLUNTARY POLITICAL ACTION COMMITTEE
#
#                             common_name  cfr_com_id com_type  ...  \
# ...

# %% [markdown]
# option --> create a utils function that reads in all files and adds the corrupted lines to a list as a temporary solution until a formal solution is found for the corrupted files.

# %%
error_files = []
error_lines = []

# NOTE: THE FUNCTION BELOW NEEDS TO BE CHANGED THE STRING SEARCHES FOR 00 THROUGHOUT THE FUNCTION. USE REGEX TO SEARCH FOR THE VALUES AT 
# THE END OF THE FILE NAME AND BASE THE FUNCTION BELOW ON THAT 

def custom_bad_line_handler(bad_line):
    """
    """
    skipped_line = []
    # Process the bad line, you can choose to log it or take some other action
    skipped_line.append(bad_line)
    
    return skipped_line

filepath = "/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet/data/Contributions/"

for file in os.listdir(filepath):
    try:
       if file.endswith('00.txt'):
        #if file contains "00" read in the headers 
            df = pd.read_csv(filepath + file, delimiter="\t", encoding="mac_roman", usecols=["doc_seq_no", "page_no", "contribution_id",
                                                                                                "cont_detail_id", "doc_stmnt_year", "doc_type_desc", 
                                                                                                "com_legal_name", "common_name", "cfr_com_id",	"com_type",	
                                                                                                "can_first_name",	"can_last_name", "contribtype",	"f_name", 
                                                                                                "l_name_or_org", "address",	"city",	"state", "zip",	"occupation", 
                                                                                                "employer",	"received_date", "amount",	"aggregate", "extra_desc"],skipinitialspace=True, quotechar = ' ', low_memory=False)
       else:
           # need to add the column names
           df = pd.read_csv(filepath + file, delimiter="\t", encoding="mac_roman", header=None, names=["doc_seq_no", "page_no", "contribution_id",
                                                                                                "cont_detail_id", "doc_stmnt_year", "doc_type_desc", 
                                                                                                "com_legal_name", "common_name", "cfr_com_id",	"com_type",	
                                                                                                "can_first_name",	"can_last_name", "contribtype",	"f_name", 
                                                                                                "l_name_or_org", "address",	"city",	"state", "zip",	"occupation", 
                                                                                       "employer",	"received_date", "amount",	"aggregate", "extra_desc"],skipinitialspace=True, quotechar = ' ', low_memory=False)

    except pd.errors.ParserError as e:
        # Handle the ParserError (e.g., print an error message)
        print(f"ParserError encountered in file: {file}")
        
        e_message = str(e)
        # Add the file to the list of error_files
        error_files.append(file)
        error_lines.append(e_message)
