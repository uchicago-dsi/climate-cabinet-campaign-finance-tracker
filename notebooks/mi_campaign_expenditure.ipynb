# %%
import pandas as pd
import os
import sys
import plotly.express as px
import ipywidgets as widgets
from IPython.display import display

module_directory = (
    "/Users/necabotheking/Documents/Github/2023-fall-clinic-climate-cabinet"
)
sys.path.append(module_directory)

from utils.preprocess_mi_campaign_data import read_expenditure_data
from utils.constants import EXP_FILEPATH, MI_EXPENDITURE_COLUMNS

# %% [markdown]
# ### Michigan Campaign Expenditure Data 2018 - 2023 Exploratory Data Analysis

# %% [markdown]
# #### Task 1: Read in the Dataset and merge into one Pandas DataFrame

# %%
campaign_dataframe_lst = []

for file in os.listdir(EXP_FILEPATH):
    filepath = EXP_FILEPATH + file
    campaign_dataframe_lst.append(
        read_expenditure_data(filepath, MI_EXPENDITURE_COLUMNS)
    )

# %%
pd.options.display.max_columns = 100
campaign_dataframe_lst[0].head(5)

# the gub_account_type and election type are missing?
# Out:
#    doc_seq_no expenditure_type gub_account_type gub_elec_type  page_no  \
# 0      488507               1B                                       0
# 1      488507               1B                                       0
# 2      488507               1B                                       0
# 3      488507               1B                                       0
# 4      488507               1B                                       0
#
#    expense_id  detail_id  doc_stmnt_year doc_type_desc  \
# 0        4100          0            2020     ANNUAL CS
# 1        4101          0            2020     ANNUAL CS
# 2        4108          0            2020     ANNUAL CS
# 3        4109          0            2020     ANNUAL CS
# 4        4110          0            2020     ANNUAL CS
#
#                                       com_legal_name  \
# 0  COMMITTEE TO ELECT CHARIS LEE FOR STATE REPRES...
# 1  COMMITTEE TO ELECT CHARIS LEE FOR STATE REPRES...
# 2  COMMITTEE TO ELECT CHARIS LEE FOR STATE REPRES...
# 3  COMMITTEE TO ELECT CHARIS LEE FOR STATE REPRES...
# 4  COMMITTEE TO ELECT CHARIS LEE FOR STATE REPRES...
#
#                             common_name  cfr_com_id com_type schedule_desc  \
# 0  COMMITTEE TO ELECT CHARIS LEE FOR ST    519354.0      CAN        DIRECT
# 1  COMMITTEE TO ELECT CHARIS LEE FOR ST    519354.0      CAN        DIRECT
# 2  COMMITTEE TO ELECT CHARIS LEE FOR ST    519354.0      CAN        DIRECT
# 3  COMMITTEE TO ELECT CHARIS LEE FOR ST    519354.0      CAN        DIRECT
# 4  COMMITTEE TO ELECT CHARIS LEE FOR ST    519354.0      CAN        DIRECT
#
#                     exp_desc                     purpose extra_desc f_name  \
# 0             COMPUTER COSTS     CHUNIQ INPOWER GOSQ.COM        NaN    NaN
# 1          PRINT ADVERTISING  SAWICKI & SON 313-962-2725        NaN    NaN
# 2  MAILING,POSTAGE,BULK RATE                     STAPLES        NaN    NaN
# 3  MAILING,POSTAGE,BULK RATE                     STAPLES        NaN    NaN
# 4     CONSULTATION, RESEARCH            FIELD OPERATIONS        NaN    NaN
#
#                            lname_or_org          address  \
# 0  COMMITTEE TO ELECT CHARIS LEE         1133 FAIRFAX ST
# 1  COMMITTEE TO ELECT CHARIS LEE         1133 FAIRFAX ST
# 2  COMMITTEE TO ELECT CHARIS LEE         1133 FAIRFAX ST
# 3  COMMITTEE TO ELECT CHARIS LEE         1133 FAIRFAX ST
# 4  COMMITTEE TO ELECT CHARIS LEE         1133 FAIRFAX ST
#
#                    city state         zip    exp_date  amount state_loc  \
# 0  FLINT                   MI  48505-0000  11/15/2019  354.28       NaN
# 1  FLINT                   MI  48505-0000  12/02/2019  500.00       NaN
# 2  FLINT                   MI  48505-0000  11/26/2019  101.61       NaN
# 3  FLINT                   MI  48505-0000  11/26/2019  131.18       NaN
# 4  FLINT                   MI  48505-0000  12/03/2019  100.65       NaN
#
#    supp_opp can_or_ballot county debt_payment vend_name vend_addr vend_city  \
# 0       NaN           NaN    NaN          NaN       NaN       NaN       NaN
# 1       NaN           NaN    NaN          NaN       NaN       NaN       NaN
# 2       NaN           NaN    NaN          NaN       NaN       NaN       NaN
# 3       NaN           NaN    NaN          NaN       NaN       NaN       NaN
# 4       NaN           NaN    NaN          NaN       NaN       NaN       NaN
#
#   vend_state vend_zip  gotv_ink_ind fundraiser
# 0        NaN      NaN           NaN        NaN
# 1        NaN      NaN           NaN        NaN
# 2        NaN      NaN           NaN        NaN
# 3        NaN      NaN           NaN          X
# 4        NaN      NaN           NaN        NaN

# %%
merged_campaign_df = pd.concat(campaign_dataframe_lst)

# %%
merged_campaign_df.dtypes
# Out:
# doc_seq_no            int64
# expenditure_type     object
# gub_account_type     object
# gub_elec_type        object
# page_no               int64
# expense_id            int64
# detail_id             int64
# doc_stmnt_year        int64
# doc_type_desc        object
# com_legal_name       object
# common_name          object
# cfr_com_id          float64
# com_type             object
# schedule_desc        object
# exp_desc             object
# purpose              object
# extra_desc           object
# f_name               object
# lname_or_org         object
# address              object
# city                 object
# state                object
# zip                  object
# exp_date             object
# amount               object
# state_loc            object
# supp_opp            float64
# can_or_ballot        object
# county               object
# debt_payment         object
# vend_name            object
# vend_addr            object
# vend_city            object
# vend_state           object
# vend_zip             object
# gotv_ink_ind         object
# fundraiser           object
# dtype: object

# %%
merged_campaign_df["amount"] = pd.to_numeric(
    merged_campaign_df["amount"], errors="coerce"
)

# %%
merged_campaign_df.dtypes
# Out:
# doc_seq_no            int64
# expenditure_type     object
# gub_account_type     object
# gub_elec_type        object
# page_no               int64
# expense_id            int64
# detail_id             int64
# doc_stmnt_year        int64
# doc_type_desc        object
# com_legal_name       object
# common_name          object
# cfr_com_id          float64
# com_type             object
# schedule_desc        object
# exp_desc             object
# purpose              object
# extra_desc           object
# f_name               object
# lname_or_org         object
# address              object
# city                 object
# state                object
# zip                  object
# exp_date             object
# amount              float64
# state_loc            object
# supp_opp            float64
# can_or_ballot        object
# county               object
# debt_payment         object
# vend_name            object
# vend_addr            object
# vend_city            object
# vend_state           object
# vend_zip             object
# gotv_ink_ind         object
# fundraiser           object
# dtype: object

# %%
null_percentage = (merged_campaign_df.isna().mean() * 100).reset_index()
null_percentage.columns = ["Column Name", "Missing Percentage"]

# The percentage of null values in each column is as follows below
display(null_percentage)
# Out:
#          Column Name  Missing Percentage
# 0         doc_seq_no            0.000000
# 1   expenditure_type            0.000000
# 2   gub_account_type            0.000000
# 3      gub_elec_type            0.000000
# 4            page_no            0.000000
# 5         expense_id            0.000000
# 6          detail_id            0.000000
# 7     doc_stmnt_year            0.000000
# 8      doc_type_desc            0.000000
# 9     com_legal_name            0.010585
# 10       common_name            0.000000
# 11        cfr_com_id            0.010585
# 12          com_type            0.000000
# 13     schedule_desc            0.000000
# 14          exp_desc           39.922068
# 15           purpose            0.459811
# 16        extra_desc           99.989662
# 17            f_name           87.890335
# 18      lname_or_org            0.044553
# 19           address            1.046882
# 20              city            0.841346
# 21             state            0.803684
# 22               zip            1.090451
# 23          exp_date            0.000492
# 24            amount            0.045292
# 25         state_loc           95.452352
# 26          supp_opp           88.568728
# 27     can_or_ballot           74.145239
# 28            county           77.977571
# 29      debt_payment           99.005056
# 30         vend_name           98.027835
# 31         vend_addr           98.781304
# 32         vend_city           98.782781
# 33        vend_state           98.782289
# 34          vend_zip           98.787950
# 35      gotv_ink_ind           99.881601
# 36        fundraiser           97.396210

# %% [markdown]
# #### Top 10 recipients

# %%
# Top Contributions supporting a Candidate or Ballot Issue

top_10_individual_recipients = merged_campaign_df[
    (merged_campaign_df["lname_or_org"].notnull())
    & (merged_campaign_df["f_name"].notnull())
]
top_10_individual_recipients = (
    top_10_individual_recipients.groupby(
        ["f_name", "lname_or_org", "supp_opp", "can_or_ballot"]
    )["amount"]
    .sum()
    .reset_index()
)
top_10_individual_recipients = top_10_individual_recipients.sort_values(
    by="amount", ascending=False
).head(10)
display(top_10_individual_recipients)
# Out:
#                    f_name                          lname_or_org  supp_opp  \
# 202  HEATHER               RICKETTS                                   1.0
# 156  DENNIS                LENNOX                                     1.0
# 283  KATHRYN               FAHEY                                      1.0
# 210  JACK                  JENNINGS                                   1.0
# 436  SCOTT                 DREXEL                                     1.0
# 219  JAMES                 LANCASTER                                  1.0
# 316  LENORE                GOLDMAN                                    1.0
# 451  TALYCE                MURRAY                                     1.0
# 295  KEVIN                 OGLESBY                                    1.0
# 416  ROBERT                DRAHEIM                                    1.0
#
#                  can_or_ballot    amount
# 202     VOTERS NOT POLITICIANS  78985.66
# 156  YES ON NAT'L POPULAR VOTE  63105.23
# 283     VOTERS NOT POLITICIANS  60235.15
# 210     VOTERS NOT POLITICIANS  58293.37
# 436  YES ON NAT'L POPULAR VOTE  51488.27
# 219     VOTERS NOT POLITICIANS  45817.00
# 316     VOTERS NOT POLITICIANS  39219.42
# 451                2022 PROP 2  34147.19
# 295           REPEAL 1945PA302  32400.00
# 416     VOTERS NOT POLITICIANS  31871.04

# %%
# Top Contributions opposing an Office or Ballot Issue

# Need to get the sum for each individual candidate, not the highest amount

top_10_individual_recipients_opposing = merged_campaign_df[
    (merged_campaign_df["lname_or_org"].notnull())
    & (merged_campaign_df["f_name"].notnull())
    & (merged_campaign_df["supp_opp"] == 2.0)
]
top_10_individual_recipients_opposing = (
    top_10_individual_recipients_opposing.groupby(
        ["f_name", "lname_or_org", "supp_opp", "can_or_ballot"]
    )["amount"]
    .sum()
    .reset_index()
)
top_10_individual_recipients_opposing = (
    top_10_individual_recipients_opposing.sort_values(
        by="amount", ascending=False
    ).head(10)
)
display(top_10_individual_recipients_opposing)
# Out:
#                   f_name                          lname_or_org  supp_opp  \
# 48  MICHAEL               GILMORE ESQ.                               2.0
# 45  LINDA                 KOJIRO                                     2.0
# 4   BRADLEY               OCONNER                                    2.0
# 37  JAY                   ANDERSON                                   2.0
# 3   BLAKE                 EDMUNDS                                    2.0
# 8   CLAUDIA               RODRIGUEZ                                  2.0
# 18  CLAUDIA               RODRIGUEZ                                  2.0
# 13  CLAUDIA               RODRIGUEZ                                  2.0
# 17  CLAUDIA               RODRIGUEZ                                  2.0
# 16  CLAUDIA               RODRIGUEZ                                  2.0
#
#           can_or_ballot    amount
# 48       SECURE MI VOTE  18532.26
# 45  MICHIGAN PROPOSAL 3   5550.00
# 4       STEPHEN RANZINI    500.00
# 37          MIKE DUGGAN    430.00
# 3      GRETCHEN WHITMER    293.30
# 8          BRIAN MEAKIN    284.10
# 18          ROGER HAUCK    227.28
# 13      GREG VANWOERKOM    227.28
# 17          LARRY INMAN    227.28
# 16       JOSEPH BELLINO    227.28

# %%
# Top recipients of expenditures for organizations

top_10_org_recipients = merged_campaign_df[merged_campaign_df["f_name"].isnull()]
top_10_org_recipients = (
    top_10_org_recipients.groupby(["lname_or_org", "purpose"])["amount"]
    .sum()
    .reset_index()
)
top_10_org_recipients = top_10_org_recipients.sort_values(
    by="amount", ascending=False
).head(10)
display(top_10_org_recipients)
# Out:
#                                 lname_or_org                         purpose  \
# 68303   KELLY SCOTT & MADISON INC                         MEDIA AD PLACEMENT
# 54063   GMMB                                                       MEDIA BUY
# 86686   NATIONAL PETITION MANAGEMENT          PETITIONS; SIGNATURE GATHERING
# 82390   MICHIGAN DEMOCRATIC STATE CENTRAL CO                    CONTRIBUTION
# 54071   GMMB                                                  TV ADVERTISING
# 46123   FIELD WORKS LLC                          PETITION GATHERING EXPENSES
# 69753   KNOW-HOW STRATEGIES                                        MEDIA BUY
# 111062  TARGETED PLATFORM MEDIA LLC                              ADVERTISING
# 109018  STRATEGIC MEDIA PLACEMENT INC                           PLACED MEDIA
# 46151   FIELDWORKS LLC                                   SIGNATURE GATHERING
#
#              amount
# 68303   17453108.00
# 54063   16954706.00
# 86686    9901099.24
# 82390    8157143.18
# 54071    7477029.48
# 46123    7340198.76
# 69753    6671420.08
# 111062   6551748.27
# 109018   5224802.00
# 46151    5209286.84
