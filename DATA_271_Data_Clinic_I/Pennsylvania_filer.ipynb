# %%
import pandas as pd

# %%
df_2020 = pd.read_csv("2020/filer_2020.txt", names=['FILERID','EYEAR','CYCLE','AMEND','TERMINATE','FILERTYPE',\
                                                    'FILERNAME','OFFICE','DISTRICT','PARTY','ADDRESS1','ADDRESS2',\
                                                    'CITY','STATE','ZIPCODE','COUNTY','PHONE','BEGINNING','MONETARY',\
                                                    'INKIND'])
df_2020
# Out:
#        FILERID  EYEAR  CYCLE AMEND TERMINATE  FILERTYPE  \
# 0     20180224   2020      1     N         N        2.0
# 1     20190187   2020      1     N         N        2.0
# 2      7900160   2020      2     N         Y        2.0
# 3      8300175   2020      1     N         N        3.0
# 4      8200003   2020      1     N         N        2.0
# ...        ...    ...    ...   ...       ...        ...
# 8657  20180517   2020      7     N         N        2.0
# 8658  20190257   2020      7     N         N        2.0
# 8659  20200181   2020      6     N         N        2.0
# 8660  20200227   2020      2     N         N        2.0
# 8661  20200227   2020      5     N         N        2.0
#
#                                               FILERNAME OFFICE  DISTRICT  \
# 0                    EAST NANTMEAL DEMOCRATIC COMMITTEE    NaN       NaN
# 1             WESTERN CUMBERLAND COUNTY REPUBLICAN CLUB    NaN       NaN
# ...

# %%
df_2015=pd.read_csv("2015/filer_2015.txt", names=['FILERID','EYEAR','CYCLE','AMEND','TERMINATE','FILERTYPE',\
                                                    'FILERNAME','OFFICE','DISTRICT','PARTY','ADDRESS1','ADDRESS2',\
                                                    'CITY','STATE','ZIPCODE','COUNTY','PHONE','BEGINNING','MONETARY',\
                                                    'INKIND'])
df_2015
# Out:
#        FILERID  EYEAR  CYCLE AMEND TERMINATE  FILERTYPE  \
# 0      2008291   2015      6     N         N          2
# 1     20150285   2015      6     N         N          2
# 2      2006371   2015      6     N         N          2
# 3      2007295   2015      6     N         N          2
# 4      8000489   2015      6     N         N          2
# ...        ...    ...    ...   ...       ...        ...
# 7114   2007187   2015      6     N         N          2
# 7115   7900200   2015      6     N         N          2
# 7116   7900636   2015      6     N         N          2
# 7117   8200547   2015      6     N         N          2
# 7118   9700166   2015      6     N         N          2
#
#                                     FILERNAME OFFICE  DISTRICT PARTY  \
# 0            FRANKLIN COUNTY REAGAN COALITION    NaN       NaN   NaN
# 1            NEXTGEN CLIMATE ACTION COMMITTEE    NaN       NaN   NaN
# 2             ZARWIN BAUM GOOD GOVERNMENT PAC    NaN       NaN   NaN
# ...
